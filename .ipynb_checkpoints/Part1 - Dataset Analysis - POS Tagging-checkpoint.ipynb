# %%
import json
import pandas as pd
import numpy as np

# nltk pos tagging 
import nltk
from nltk.tokenize import word_tokenize

# transformers-based pos tagging
from transformers import AutoModelForTokenClassification, AutoTokenizer
import tensorflow as tf

# %% [markdown]
# #### import data

# %%
# read json data
data_path = 'C:\\Users\\tanch\\Documents\\NTU\\NTU Year 3\\Sem 1\\CZ4045 Natural Language Processing\\Assignment 1\\local\\data\\reviewSelected100\\reviewSelected100.json'
reviews = []
with open(data_path,"r") as f:
    for l in f.readlines():
        reviews.append(json.loads(l))
        
# convert to dataframe
reviews_df = pd.DataFrame(reviews)

# %% [markdown]
# ## Load Transformers-based POS Tagger

# %%
model_checkpoint = "vblagoje/bert-english-uncased-finetuned-pos"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint)

# %%
def bert_generate_tags(text):
    input_ids = tokenizer(text, return_attention_mask  = False, add_special_tokens = True, return_tensors='pt')['input_ids']   # wordpiece toeknization
    logits = model(input_ids).logits                                        # model forwards pass
    ids = np.argmax(logits.detach().numpy()[0],axis = 1)                    # acquire labels for each token             
    labels = [model.config.id2label[i] for i in ids]
    return list(zip([tokenizer.decode(t) for t in input_ids[0]],labels))[1:-1]    # return labels for each token

# %% [markdown]
# ## NLTK POS Tagger

# %%
def nltk_generate_tags(text):
    text = word_tokenize(text)
    return nltk.pos_tag(text)

# %% [markdown]
# ## Randomly select 5 Sentences

# %%
seed = 85
sample_size = 5
samples = reviews_df.sample(sample_size, random_state = seed)[["review_id","text"]].reset_index(drop=True)
[len(t) for t in samples.text]
# Out:
# [129, 146, 227, 2189, 1647]

# %% [markdown]
# # Apply POS Tagging

# %% [markdown]
# ### Review 1

# %%
i = 0
review = samples.text[i]
print(review)
# Out:
# Love this place! Great place to grab a delicious sandwich and soup without spending a fortune!! My favourite is the Farmers Club!

# %%
bert_tags = bert_generate_tags(review)
nltk_tags = nltk_generate_tags(review)

# %%
print("BERT POS Tagging:             NLTK POS Tagging:")
for i in range(len(bert_tags)):
    if i >= len(nltk_tags):
        print(i,bert_tags[i])
    else:
        print(f"{i} {str(bert_tags[i]):28}{nltk_tags[i]}")
# Out:
# BERT POS Tagging:             NLTK POS Tagging:
# 0 ('love', 'VERB')            ('Love', 'VB')
# 1 ('this', 'DET')             ('this', 'DT')
# 2 ('place', 'NOUN')           ('place', 'NN')
# 3 ('!', 'PUNCT')              ('!', '.')
# 4 ('great', 'ADJ')            ('Great', 'JJ')
# 5 ('place', 'NOUN')           ('place', 'NN')
# 6 ('to', 'PART')              ('to', 'TO')
# 7 ('grab', 'VERB')            ('grab', 'VB')
# 8 ('a', 'DET')                ('a', 'DT')
# 9 ('delicious', 'ADJ')        ('delicious', 'JJ')
# 10 ('sandwich', 'NOUN')        ('sandwich', 'NN')
# 11 ('and', 'CCONJ')            ('and', 'CC')
# 12 ('soup', 'NOUN')            ('soup', 'NN')
# 13 ('without', 'SCONJ')        ('without', 'IN')
# 14 ('spending', 'VERB')        ('spending', 'VBG')
# 15 ('a', 'DET')                ('a', 'DT')
# 16 ('fortune', 'NOUN')         ('fortune', 'NN')
# 17 ('!', 'PUNCT')              ('!', '.')
# 18 ('!', 'PUNCT')              ('!', '.')
# 19 ('my', 'PRON')              ('My', 'PRP$')
# 20 ('favourite', 'NOUN')       ('favourite', 'NN')
# 21 ('is', 'AUX')               ('is', 'VBZ')
# 22 ('the', 'DET')              ('the', 'DT')
# 23 ('farmers', 'PROPN')        ('Farmers', 'NNP')
# 24 ('club', 'PROPN')           ('Club', 'NNP')
# 25 ('!', 'PUNCT')              ('!', '.')

# %% [markdown]
# ### Review 2

# %%
i = 1
review = samples.text[i]
print(review)
# Out:
# Large space for group events and great service. Food is decent as well - a good go to if you're in the area and just craving drinks and basic food

# %%
bert_tags = bert_generate_tags(review)
nltk_tags = nltk_generate_tags(review)

# %%
print("BERT POS Tagging:             NLTK POS Tagging:")
for i in range(len(bert_tags)):
    if i >= len(nltk_tags):
        print(i,bert_tags[i])
    else:
        print(f"{i} {str(bert_tags[i]):28}{nltk_tags[i]}")
# Out:
# BERT POS Tagging:             NLTK POS Tagging:
# 0 ('large', 'ADJ')            ('Large', 'JJ')
# 1 ('space', 'NOUN')           ('space', 'NN')
# 2 ('for', 'ADP')              ('for', 'IN')
# 3 ('group', 'NOUN')           ('group', 'NN')
# 4 ('events', 'NOUN')          ('events', 'NNS')
# 5 ('and', 'CCONJ')            ('and', 'CC')
# 6 ('great', 'ADJ')            ('great', 'JJ')
# 7 ('service', 'NOUN')         ('service', 'NN')
# 8 ('.', 'PUNCT')              ('.', '.')
# 9 ('food', 'NOUN')            ('Food', 'NNP')
# 10 ('is', 'AUX')               ('is', 'VBZ')
# 11 ('decent', 'ADJ')           ('decent', 'JJ')
# 12 ('as', 'ADV')               ('as', 'RB')
# 13 ('well', 'ADV')             ('well', 'RB')
# 14 ('-', 'PUNCT')              ('-', ':')
# 15 ('a', 'DET')                ('a', 'DT')
# 16 ('good', 'ADJ')             ('good', 'JJ')
# 17 ('go', 'NOUN')              ('go', 'NN')
# 18 ('to', 'ADP')               ('to', 'TO')
# 19 ('if', 'SCONJ')             ('if', 'IN')
# 20 ('you', 'PRON')             ('you', 'PRP')
# 21 ("'", 'AUX')                ("'re", 'VBP')
# 22 ('re', 'AUX')               ('in', 'IN')
# 23 ('in', 'ADP')               ('the', 'DT')
# 24 ('the', 'DET')              ('area', 'NN')
# 25 ('area', 'NOUN')            ('and', 'CC')
# 26 ('and', 'CCONJ')            ('just', 'RB')
# 27 ('just', 'ADV')             ('craving', 'VBG')
# 28 ('craving', 'VERB')         ('drinks', 'NNS')
# 29 ('drinks', 'NOUN')          ('and', 'CC')
# 30 ('and', 'CCONJ')            ('basic', 'JJ')
# 31 ('basic', 'ADJ')            ('food', 'NN')
# 32 ('food', 'NOUN')

# %% [markdown]
# ### Review 3

# %%
i = 2
review = samples.text[i]
print(review)
# Out:
# Chettinad Chicken masala the sauce is good but chicken little pieces bones they cut the chicken tight into 4 not good for the value $12.99  rate poor
# Boneless chicken biriyani was excellent.
#
# Fish Fry was not fresh very fishy.

# %%
bert_tags = bert_generate_tags(review)
nltk_tags = nltk_generate_tags(review)

# %%
print("BERT POS Tagging:             NLTK POS Tagging:")
for i in range(len(bert_tags)):
    if i >= len(nltk_tags):
        print(i,bert_tags[i])
    else:
        print(f"{i} {str(bert_tags[i]):28}{nltk_tags[i]}")
# Out:
# BERT POS Tagging:             NLTK POS Tagging:
# 0 ('chet', 'NOUN')            ('Chettinad', 'NNP')
# 1 ('##tina', 'NOUN')          ('Chicken', 'NNP')
# 2 ('##d', 'PROPN')            ('masala', 'VBD')
# 3 ('chicken', 'NOUN')         ('the', 'DT')
# 4 ('mas', 'NOUN')             ('sauce', 'NN')
# 5 ('##ala', 'NOUN')           ('is', 'VBZ')
# 6 ('the', 'DET')              ('good', 'JJ')
# 7 ('sauce', 'NOUN')           ('but', 'CC')
# 8 ('is', 'AUX')               ('chicken', 'JJ')
# 9 ('good', 'ADJ')             ('little', 'JJ')
# 10 ('but', 'CCONJ')            ('pieces', 'NNS')
# 11 ('chicken', 'NOUN')         ('bones', 'NNS')
# 12 ('little', 'ADJ')           ('they', 'PRP')
# 13 ('pieces', 'NOUN')          ('cut', 'VBD')
# 14 ('bones', 'VERB')           ('the', 'DT')
# 15 ('they', 'PRON')            ('chicken', 'NN')
# 16 ('cut', 'VERB')             ('tight', 'VBD')
# 17 ('the', 'DET')              ('into', 'IN')
# 18 ('chicken', 'NOUN')         ('4', 'CD')
# 19 ('tight', 'ADV')            ('not', 'RB')
# 20 ('into', 'ADP')             ('good', 'JJ')
# 21 ('4', 'NUM')                ('for', 'IN')
# 22 ('not', 'ADV')              ('the', 'DT')
# 23 ('good', 'ADJ')             ('value', 'NN')
# 24 ('for', 'ADP')              ('$', '$')
# 25 ('the', 'DET')              ('12.99', 'CD')
# 26 ('value', 'NOUN')           ('rate', 'NN')
# 27 ('$', 'SYM')                ('poor', 'JJ')
# 28 ('12', 'NUM')               ('Boneless', 'NNP')
# 29 ('.', 'PUNCT')              ('chicken', 'NN')
# 30 ('99', 'NUM')               ('biriyani', 'NN')
# 31 ('rate', 'NOUN')            ('was', 'VBD')
# 32 ('poor', 'ADJ')             ('excellent', 'JJ')
# 33 ('bone', 'ADJ')             ('.', '.')
# 34 ('##less', 'ADJ')           ('Fish', 'JJ')
# 35 ('chicken', 'NOUN')         ('Fry', 'NNP')
# 36 ('bi', 'PROPN')             ('was', 'VBD')
# 37 ('##ri', 'PROPN')           ('not', 'RB')
# 38 ('##yan', 'PROPN')          ('fresh', 'JJ')
# 39 ('##i', 'PROPN')            ('very', 'RB')
# 40 ('was', 'AUX')              ('fishy', 'JJ')
# 41 ('excellent', 'ADJ')        ('.', '.')
# 42 ('.', 'PUNCT')
# 43 ('fish', 'NOUN')
# 44 ('fry', 'NOUN')
# 45 ('was', 'AUX')
# 46 ('not', 'PART')
# 47 ('fresh', 'ADJ')
# 48 ('very', 'ADV')
# 49 ('fish', 'ADJ')
# 50 ('##y', 'ADJ')
# 51 ('.', 'PUNCT')

# %% [markdown]
# ### Review 4

# %%
i = 3
review = samples.text[i]
print(review)
# Out:
# For years I have been going to the strip mall aka food court mall near the north west corner of Eglington and Dixie.  I've seen some businesses come and go through that time and because of that you get the new place every once in a while.  The Burger Factory has been here for a while now and although I hadn't been, I knew it was there.  The fact is this area of Dixie road between Eglinton and Matheson has MANY places to eat.  If I were a new business in this area with this much competition I'd probably be like, yikes!  Still it's a busy enough area to warrant the kind of dense concentration and saturation of restaurants I suppose.
#
# The Burger Factory is part of the north end of the strip mall, opposite the long time mainstays like Bamiyan Kabob and Chang & Huang's which are on the south side.  My family just had an early dinner and Chang's and my brother was telling me that the Burger Factory has funnel cakes and that we should go for it as a group dessert.  I was like OK, sure.  That sounds like a plan.
#
# A short walk across the parking lot brought us into the Burger Factory which seemed to be somewhat busy with people eating their burgers and some waiting for their take out.  Waiting in line allowed me to have a look at their menu which basically look like a nice selection of burger choices some of which look to be larger such as doubles and even triples.  One notable thing is that this place is Halal much like many of the other establishments in the surrounding area.
#
# We had just eaten but looking at their selection I'd come back for a burger.  My brother ate there before and said it was good.  I'd probably be interested in that Juicy Lucy which is a Minneapolis thing, basically a burger stuffed with cheese that melts inside... yum!
#
# Although we were just there for a funnel cake I didn't have to wait very long.  What an attractive serving.  With the strawberry topping and tax it came out to about 10 bucks.  Icing sugar, hot, crunchy, doughy and just plain good.  It was a perfect dessert to share after having a spicy and savory meal across the parking lot.
#
# As for the burgers that'll have to be another visit but I'm already looking forward to it.

# %%
bert_tags = bert_generate_tags(review)
nltk_tags = nltk_generate_tags(review)

# %%
print("BERT POS Tagging:             NLTK POS Tagging:")
for i in range(len(bert_tags)):
    if i >= len(nltk_tags):
        print(i,bert_tags[i])
    else:
        print(f"{i} {str(bert_tags[i]):28}{nltk_tags[i]}")
# Out:
# BERT POS Tagging:             NLTK POS Tagging:
# 0 ('for', 'ADP')              ('For', 'IN')
# 1 ('years', 'NOUN')           ('years', 'NNS')
# 2 ('i', 'PRON')               ('I', 'PRP')
# 3 ('have', 'AUX')             ('have', 'VBP')
# 4 ('been', 'AUX')             ('been', 'VBN')
# 5 ('going', 'VERB')           ('going', 'VBG')
# 6 ('to', 'ADP')               ('to', 'TO')
# 7 ('the', 'DET')              ('the', 'DT')
# 8 ('strip', 'NOUN')           ('strip', 'NN')
# 9 ('mall', 'NOUN')            ('mall', 'NN')
# 10 ('aka', 'X')                ('aka', 'VBD')
# 11 ('food', 'PROPN')           ('food', 'NN')
# 12 ('court', 'PROPN')          ('court', 'NN')
# 13 ('mall', 'PROPN')           ('mall', 'NN')
# 14 ('near', 'ADP')             ('near', 'IN')
# 15 ('the', 'DET')              ('the', 'DT')
# 16 ('north', 'ADJ')            ('north', 'JJ')
# 17 ('west', 'ADJ')             ('west', 'JJ')
# 18 ('corner', 'NOUN')          ('corner', 'NN')
# 19 ('of', 'ADP')               ('of', 'IN')
# 20 ('e', 'PROPN')              ('Eglington', 'NNP')
# 21 ('##gling', 'PROPN')        ('and', 'CC')
# 22 ('##ton', 'PROPN')          ('Dixie', 'NNP')
# 23 ('and', 'CCONJ')            ('.', '.')
# 24 ('dixie', 'PROPN')          ('I', 'PRP')
# 25 ('.', 'PUNCT')              ("'ve", 'VBP')
# 26 ('i', 'PRON')               ('seen', 'VBN')
# 27 ("'", 'AUX')                ('some', 'DT')
# 28 ('ve', 'AUX')               ('businesses', 'NNS')
# 29 ('seen', 'VERB')            ('come', 'VBP')
# 30 ('some', 'DET')             ('and', 'CC')
# 31 ('businesses', 'NOUN')      ('go', 'VBP')
# 32 ('come', 'VERB')            ('through', 'IN')
# 33 ('and', 'CCONJ')            ('that', 'DT')
# 34 ('go', 'VERB')              ('time', 'NN')
# 35 ('through', 'ADP')          ('and', 'CC')
# 36 ('that', 'DET')             ('because', 'IN')
# 37 ('time', 'NOUN')            ('of', 'IN')
# 38 ('and', 'CCONJ')            ('that', 'DT')
# 39 ('because', 'ADP')          ('you', 'PRP')
# 40 ('of', 'ADP')               ('get', 'VBP')
# 41 ('that', 'PRON')            ('the', 'DT')
# 42 ('you', 'PRON')             ('new', 'JJ')
# 43 ('get', 'VERB')             ('place', 'NN')
# 44 ('the', 'DET')              ('every', 'DT')
# 45 ('new', 'ADJ')              ('once', 'RB')
# 46 ('place', 'NOUN')           ('in', 'IN')
# 47 ('every', 'DET')            ('a', 'DT')
# 48 ('once', 'NOUN')            ('while', 'NN')
# 49 ('in', 'ADP')               ('.', '.')
# 50 ('a', 'DET')                ('The', 'DT')
# 51 ('while', 'NOUN')           ('Burger', 'NNP')
# 52 ('.', 'PUNCT')              ('Factory', 'NNP')
# 53 ('the', 'DET')              ('has', 'VBZ')
# 54 ('burger', 'PROPN')         ('been', 'VBN')
# 55 ('factory', 'PROPN')        ('here', 'RB')
# 56 ('has', 'AUX')              ('for', 'IN')
# 57 ('been', 'AUX')             ('a', 'DT')
# 58 ('here', 'ADV')             ('while', 'NN')
# 59 ('for', 'ADP')              ('now', 'RB')
# 60 ('a', 'DET')                ('and', 'CC')
# 61 ('while', 'NOUN')           ('although', 'IN')
# 62 ('now', 'ADV')              ('I', 'PRP')
# 63 ('and', 'CCONJ')            ('had', 'VBD')
# 64 ('although', 'SCONJ')       ("n't", 'RB')
# 65 ('i', 'PRON')               ('been', 'VBN')
# 66 ('hadn', 'AUX')             (',', ',')
# 67 ("'", 'PART')               ('I', 'PRP')
# 68 ('t', 'PART')               ('knew', 'VBD')
# 69 ('been', 'VERB')            ('it', 'PRP')
# 70 (',', 'PUNCT')              ('was', 'VBD')
# 71 ('i', 'PRON')               ('there', 'RB')
# 72 ('knew', 'VERB')            ('.', '.')
# 73 ('it', 'PRON')              ('The', 'DT')
# 74 ('was', 'AUX')              ('fact', 'NN')
# 75 ('there', 'ADV')            ('is', 'VBZ')
# 76 ('.', 'PUNCT')              ('this', 'DT')
# 77 ('the', 'DET')              ('area', 'NN')
# 78 ('fact', 'NOUN')            ('of', 'IN')
# 79 ('is', 'VERB')              ('Dixie', 'NNP')
# 80 ('this', 'DET')             ('road', 'NN')
# 81 ('area', 'NOUN')            ('between', 'IN')
# 82 ('of', 'ADP')               ('Eglinton', 'NNP')
# 83 ('dixie', 'PROPN')          ('and', 'CC')
# 84 ('road', 'PROPN')           ('Matheson', 'NNP')
# 85 ('between', 'ADP')          ('has', 'VBZ')
# 86 ('e', 'PROPN')              ('MANY', 'JJ')
# 87 ('##gli', 'PROPN')          ('places', 'NNS')
# 88 ('##nton', 'PROPN')         ('to', 'TO')
# 89 ('and', 'CCONJ')            ('eat', 'VB')
# 90 ('math', 'PROPN')           ('.', '.')
# 91 ('##eson', 'PROPN')         ('If', 'IN')
# 92 ('has', 'VERB')             ('I', 'PRP')
# 93 ('many', 'ADJ')             ('were', 'VBD')
# 94 ('places', 'NOUN')          ('a', 'DT')
# 95 ('to', 'PART')              ('new', 'JJ')
# 96 ('eat', 'VERB')             ('business', 'NN')
# 97 ('.', 'PUNCT')              ('in', 'IN')
# 98 ('if', 'SCONJ')             ('this', 'DT')
# 99 ('i', 'PRON')               ('area', 'NN')
# 100 ('were', 'AUX')             ('with', 'IN')
# 101 ('a', 'DET')                ('this', 'DT')
# 102 ('new', 'ADJ')              ('much', 'JJ')
# 103 ('business', 'NOUN')        ('competition', 'NN')
# 104 ('in', 'ADP')               ('I', 'PRP')
# 105 ('this', 'DET')             ("'d", 'MD')
# 106 ('area', 'NOUN')            ('probably', 'RB')
# 107 ('with', 'ADP')             ('be', 'VB')
# 108 ('this', 'DET')             ('like', 'IN')
# 109 ('much', 'ADJ')             (',', ',')
# 110 ('competition', 'NOUN')     ('yikes', 'UH')
# 111 ('i', 'PRON')               ('!', '.')
# 112 ("'", 'AUX')                ('Still', 'RB')
# 113 ('d', 'AUX')                ('it', 'PRP')
# 114 ('probably', 'ADV')         ("'s", 'VBZ')
# 115 ('be', 'AUX')               ('a', 'DT')
# 116 ('like', 'INTJ')            ('busy', 'JJ')
# 117 (',', 'PUNCT')              ('enough', 'RB')
# 118 ('yi', 'INTJ')              ('area', 'NN')
# 119 ('##kes', 'INTJ')           ('to', 'TO')
# 120 ('!', 'PUNCT')              ('warrant', 'VB')
# 121 ('still', 'ADV')            ('the', 'DT')
# 122 ('it', 'PRON')              ('kind', 'NN')
# 123 ("'", 'AUX')                ('of', 'IN')
# 124 ('s', 'AUX')                ('dense', 'NN')
# 125 ('a', 'DET')                ('concentration', 'NN')
# 126 ('busy', 'ADJ')             ('and', 'CC')
# 127 ('enough', 'ADJ')           ('saturation', 'NN')
# 128 ('area', 'NOUN')            ('of', 'IN')
# 129 ('to', 'PART')              ('restaurants', 'NNS')
# 130 ('warrant', 'VERB')         ('I', 'PRP')
# 131 ('the', 'DET')              ('suppose', 'VBP')
# 132 ('kind', 'NOUN')            ('.', '.')
# 133 ('of', 'ADP')               ('The', 'DT')
# 134 ('dense', 'ADJ')            ('Burger', 'NNP')
# 135 ('concentration', 'NOUN')   ('Factory', 'NNP')
# 136 ('and', 'CCONJ')            ('is', 'VBZ')
# 137 ('sat', 'NOUN')             ('part', 'NN')
# 138 ('##uration', 'NOUN')       ('of', 'IN')
# 139 ('of', 'ADP')               ('the', 'DT')
# 140 ('restaurants', 'NOUN')     ('north', 'JJ')
# 141 ('i', 'PRON')               ('end', 'NN')
# 142 ('suppose', 'VERB')         ('of', 'IN')
# 143 ('.', 'PUNCT')              ('the', 'DT')
# 144 ('the', 'DET')              ('strip', 'NN')
# 145 ('burger', 'PROPN')         ('mall', 'NN')
# 146 ('factory', 'PROPN')        (',', ',')
# 147 ('is', 'AUX')               ('opposite', 'IN')
# 148 ('part', 'NOUN')            ('the', 'DT')
# 149 ('of', 'ADP')               ('long', 'JJ')
# 150 ('the', 'DET')              ('time', 'NN')
# 151 ('north', 'ADJ')            ('mainstays', 'NNS')
# 152 ('end', 'NOUN')             ('like', 'IN')
# 153 ('of', 'ADP')               ('Bamiyan', 'NNP')
# 154 ('the', 'DET')              ('Kabob', 'NNP')
# 155 ('strip', 'NOUN')           ('and', 'CC')
# 156 ('mall', 'NOUN')            ('Chang', 'NNP')
# 157 (',', 'PUNCT')              ('&', 'CC')
# 158 ('opposite', 'ADP')         ('Huang', 'NNP')
# 159 ('the', 'DET')              ("'s", 'POS')
# 160 ('long', 'ADJ')             ('which', 'WDT')
# 161 ('time', 'NOUN')            ('are', 'VBP')
# 162 ('main', 'NOUN')            ('on', 'IN')
# 163 ('##sta', 'NOUN')           ('the', 'DT')
# 164 ('##ys', 'NOUN')            ('south', 'JJ')
# 165 ('like', 'ADP')             ('side', 'NN')
# 166 ('bam', 'PROPN')            ('.', '.')
# 167 ('##iya', 'PROPN')          ('My', 'PRP$')
# 168 ('##n', 'PROPN')            ('family', 'NN')
# 169 ('ka', 'PROPN')             ('just', 'RB')
# 170 ('##bo', 'PROPN')           ('had', 'VBD')
# 171 ('##b', 'PROPN')            ('an', 'DT')
# 172 ('and', 'CCONJ')            ('early', 'JJ')
# 173 ('chang', 'PROPN')          ('dinner', 'NN')
# 174 ('&', 'CCONJ')              ('and', 'CC')
# 175 ('huang', 'PROPN')          ('Chang', 'NNP')
# 176 ("'", 'PART')               ("'s", 'POS')
# 177 ('s', 'PART')               ('and', 'CC')
# 178 ('which', 'PRON')           ('my', 'PRP$')
# 179 ('are', 'AUX')              ('brother', 'NN')
# 180 ('on', 'ADP')               ('was', 'VBD')
# 181 ('the', 'DET')              ('telling', 'VBG')
# 182 ('south', 'ADJ')            ('me', 'PRP')
# 183 ('side', 'NOUN')            ('that', 'IN')
# 184 ('.', 'PUNCT')              ('the', 'DT')
# 185 ('my', 'PRON')              ('Burger', 'NNP')
# 186 ('family', 'NOUN')          ('Factory', 'NNP')
# 187 ('just', 'ADV')             ('has', 'VBZ')
# 188 ('had', 'VERB')             ('funnel', 'VBN')
# 189 ('an', 'DET')               ('cakes', 'NNS')
# 190 ('early', 'ADJ')            ('and', 'CC')
# 191 ('dinner', 'NOUN')          ('that', 'IN')
# 192 ('and', 'CCONJ')            ('we', 'PRP')
# 193 ('chang', 'PROPN')          ('should', 'MD')
# 194 ("'", 'PART')               ('go', 'VB')
# 195 ('s', 'PART')               ('for', 'IN')
# 196 ('and', 'CCONJ')            ('it', 'PRP')
# 197 ('my', 'PRON')              ('as', 'IN')
# 198 ('brother', 'NOUN')         ('a', 'DT')
# 199 ('was', 'AUX')              ('group', 'NN')
# 200 ('telling', 'VERB')         ('dessert', 'NN')
# 201 ('me', 'PRON')              ('.', '.')
# 202 ('that', 'SCONJ')           ('I', 'PRP')
# 203 ('the', 'DET')              ('was', 'VBD')
# 204 ('burger', 'PROPN')         ('like', 'IN')
# 205 ('factory', 'PROPN')        ('OK', 'NNP')
# 206 ('has', 'VERB')             (',', ',')
# 207 ('funnel', 'NOUN')          ('sure', 'NN')
# 208 ('cakes', 'NOUN')           ('.', '.')
# 209 ('and', 'CCONJ')            ('That', 'DT')
# 210 ('that', 'SCONJ')           ('sounds', 'VBZ')
# 211 ('we', 'PRON')              ('like', 'IN')
# 212 ('should', 'AUX')           ('a', 'DT')
# 213 ('go', 'VERB')              ('plan', 'NN')
# 214 ('for', 'ADP')              ('.', '.')
# 215 ('it', 'PRON')              ('A', 'DT')
# 216 ('as', 'ADP')               ('short', 'JJ')
# 217 ('a', 'DET')                ('walk', 'NN')
# 218 ('group', 'NOUN')           ('across', 'IN')
# 219 ('dessert', 'NOUN')         ('the', 'DT')
# 220 ('.', 'PUNCT')              ('parking', 'NN')
# 221 ('i', 'PRON')               ('lot', 'NN')
# 222 ('was', 'AUX')              ('brought', 'VBD')
# 223 ('like', 'INTJ')            ('us', 'PRP')
# 224 ('ok', 'INTJ')              ('into', 'IN')
# 225 (',', 'PUNCT')              ('the', 'DT')
# 226 ('sure', 'INTJ')            ('Burger', 'NNP')
# 227 ('.', 'PUNCT')              ('Factory', 'NNP')
# 228 ('that', 'PRON')            ('which', 'WDT')
# 229 ('sounds', 'VERB')          ('seemed', 'VBD')
# 230 ('like', 'ADP')             ('to', 'TO')
# 231 ('a', 'DET')                ('be', 'VB')
# 232 ('plan', 'NOUN')            ('somewhat', 'RB')
# 233 ('.', 'PUNCT')              ('busy', 'JJ')
# 234 ('a', 'DET')                ('with', 'IN')
# 235 ('short', 'ADJ')            ('people', 'NNS')
# 236 ('walk', 'NOUN')            ('eating', 'VBG')
# 237 ('across', 'ADP')           ('their', 'PRP$')
# 238 ('the', 'DET')              ('burgers', 'NNS')
# 239 ('parking', 'NOUN')         ('and', 'CC')
# 240 ('lot', 'NOUN')             ('some', 'DT')
# 241 ('brought', 'VERB')         ('waiting', 'VBG')
# 242 ('us', 'PRON')              ('for', 'IN')
# 243 ('into', 'ADP')             ('their', 'PRP$')
# 244 ('the', 'DET')              ('take', 'NN')
# 245 ('burger', 'PROPN')         ('out', 'RP')
# 246 ('factory', 'PROPN')        ('.', '.')
# 247 ('which', 'PRON')           ('Waiting', 'VBG')
# 248 ('seemed', 'VERB')          ('in', 'IN')
# 249 ('to', 'PART')              ('line', 'NN')
# 250 ('be', 'AUX')               ('allowed', 'VBN')
# 251 ('somewhat', 'ADV')         ('me', 'PRP')
# 252 ('busy', 'ADJ')             ('to', 'TO')
# 253 ('with', 'ADP')             ('have', 'VB')
# 254 ('people', 'NOUN')          ('a', 'DT')
# 255 ('eating', 'VERB')          ('look', 'NN')
# 256 ('their', 'PRON')           ('at', 'IN')
# 257 ('burger', 'NOUN')          ('their', 'PRP$')
# 258 ('##s', 'NOUN')             ('menu', 'NN')
# 259 ('and', 'CCONJ')            ('which', 'WDT')
# 260 ('some', 'DET')             ('basically', 'RB')
# 261 ('waiting', 'VERB')         ('look', 'VBP')
# 262 ('for', 'ADP')              ('like', 'IN')
# 263 ('their', 'PRON')           ('a', 'DT')
# 264 ('take', 'NOUN')            ('nice', 'JJ')
# 265 ('out', 'NOUN')             ('selection', 'NN')
# 266 ('.', 'PUNCT')              ('of', 'IN')
# 267 ('waiting', 'VERB')         ('burger', 'NN')
# 268 ('in', 'ADP')               ('choices', 'NNS')
# 269 ('line', 'NOUN')            ('some', 'DT')
# 270 ('allowed', 'VERB')         ('of', 'IN')
# 271 ('me', 'PRON')              ('which', 'WDT')
# 272 ('to', 'PART')              ('look', 'NN')
# 273 ('have', 'VERB')            ('to', 'TO')
# 274 ('a', 'DET')                ('be', 'VB')
# 275 ('look', 'NOUN')            ('larger', 'JJR')
# 276 ('at', 'ADP')               ('such', 'JJ')
# 277 ('their', 'PRON')           ('as', 'IN')
# 278 ('menu', 'NOUN')            ('doubles', 'NNS')
# 279 ('which', 'PRON')           ('and', 'CC')
# 280 ('basically', 'ADV')        ('even', 'RB')
# 281 ('look', 'VERB')            ('triples', 'NNS')
# 282 ('like', 'ADP')             ('.', '.')
# 283 ('a', 'DET')                ('One', 'CD')
# 284 ('nice', 'ADJ')             ('notable', 'JJ')
# 285 ('selection', 'NOUN')       ('thing', 'NN')
# 286 ('of', 'ADP')               ('is', 'VBZ')
# 287 ('burger', 'NOUN')          ('that', 'IN')
# 288 ('choices', 'NOUN')         ('this', 'DT')
# 289 ('some', 'DET')             ('place', 'NN')
# 290 ('of', 'ADP')               ('is', 'VBZ')
# 291 ('which', 'PRON')           ('Halal', 'NNP')
# 292 ('look', 'VERB')            ('much', 'RB')
# 293 ('to', 'PART')              ('like', 'IN')
# 294 ('be', 'AUX')               ('many', 'JJ')
# 295 ('larger', 'ADJ')           ('of', 'IN')
# 296 ('such', 'ADJ')             ('the', 'DT')
# 297 ('as', 'ADP')               ('other', 'JJ')
# 298 ('doubles', 'NOUN')         ('establishments', 'NNS')
# 299 ('and', 'CCONJ')            ('in', 'IN')
# 300 ('even', 'ADV')             ('the', 'DT')
# 301 ('triple', 'NOUN')          ('surrounding', 'JJ')
# 302 ('##s', 'NOUN')             ('area', 'NN')
# 303 ('.', 'PUNCT')              ('.', '.')
# 304 ('one', 'NUM')              ('We', 'PRP')
# 305 ('notable', 'ADJ')          ('had', 'VBD')
# 306 ('thing', 'NOUN')           ('just', 'RB')
# 307 ('is', 'VERB')              ('eaten', 'VBN')
# 308 ('that', 'SCONJ')           ('but', 'CC')
# 309 ('this', 'DET')             ('looking', 'VBG')
# 310 ('place', 'NOUN')           ('at', 'IN')
# 311 ('is', 'AUX')               ('their', 'PRP$')
# 312 ('hal', 'ADJ')              ('selection', 'NN')
# 313 ('##al', 'ADJ')             ('I', 'PRP')
# 314 ('much', 'ADV')             ("'d", 'MD')
# 315 ('like', 'ADP')             ('come', 'VB')
# 316 ('many', 'ADJ')             ('back', 'RB')
# 317 ('of', 'ADP')               ('for', 'IN')
# 318 ('the', 'DET')              ('a', 'DT')
# 319 ('other', 'ADJ')            ('burger', 'NN')
# 320 ('establishments', 'NOUN')  ('.', '.')
# 321 ('in', 'ADP')               ('My', 'PRP$')
# 322 ('the', 'DET')              ('brother', 'NN')
# 323 ('surrounding', 'VERB')     ('ate', 'NN')
# 324 ('area', 'NOUN')            ('there', 'EX')
# 325 ('.', 'PUNCT')              ('before', 'IN')
# 326 ('we', 'PRON')              ('and', 'CC')
# 327 ('had', 'AUX')              ('said', 'VBD')
# 328 ('just', 'ADV')             ('it', 'PRP')
# 329 ('eaten', 'VERB')           ('was', 'VBD')
# 330 ('but', 'CCONJ')            ('good', 'JJ')
# 331 ('looking', 'VERB')         ('.', '.')
# 332 ('at', 'ADP')               ('I', 'PRP')
# 333 ('their', 'PRON')           ("'d", 'MD')
# 334 ('selection', 'NOUN')       ('probably', 'RB')
# 335 ('i', 'PRON')               ('be', 'VB')
# 336 ("'", 'AUX')                ('interested', 'JJ')
# 337 ('d', 'AUX')                ('in', 'IN')
# 338 ('come', 'VERB')            ('that', 'DT')
# 339 ('back', 'ADV')             ('Juicy', 'NNP')
# 340 ('for', 'ADP')              ('Lucy', 'NNP')
# 341 ('a', 'DET')                ('which', 'WDT')
# 342 ('burger', 'NOUN')          ('is', 'VBZ')
# 343 ('.', 'PUNCT')              ('a', 'DT')
# 344 ('my', 'PRON')              ('Minneapolis', 'JJ')
# 345 ('brother', 'NOUN')         ('thing', 'NN')
# 346 ('ate', 'VERB')             (',', ',')
# 347 ('there', 'ADV')            ('basically', 'RB')
# 348 ('before', 'ADV')           ('a', 'DT')
# 349 ('and', 'CCONJ')            ('burger', 'NN')
# 350 ('said', 'VERB')            ('stuffed', 'NN')
# 351 ('it', 'PRON')              ('with', 'IN')
# 352 ('was', 'AUX')              ('cheese', 'NN')
# 353 ('good', 'ADJ')             ('that', 'WDT')
# 354 ('.', 'PUNCT')              ('melts', 'NNS')
# 355 ('i', 'PRON')               ('inside', 'IN')
# 356 ("'", 'AUX')                ('...', ':')
# 357 ('d', 'AUX')                ('yum', 'RB')
# 358 ('probably', 'ADV')         ('!', '.')
# 359 ('be', 'AUX')               ('Although', 'IN')
# 360 ('interested', 'ADJ')       ('we', 'PRP')
# 361 ('in', 'ADP')               ('were', 'VBD')
# 362 ('that', 'DET')             ('just', 'RB')
# 363 ('juicy', 'ADJ')            ('there', 'RB')
# 364 ('lucy', 'PROPN')           ('for', 'IN')
# 365 ('which', 'PRON')           ('a', 'DT')
# 366 ('is', 'AUX')               ('funnel', 'JJ')
# 367 ('a', 'DET')                ('cake', 'NN')
# 368 ('minneapolis', 'PROPN')    ('I', 'PRP')
# 369 ('thing', 'NOUN')           ('did', 'VBD')
# 370 (',', 'PUNCT')              ("n't", 'RB')
# 371 ('basically', 'ADV')        ('have', 'VB')
# 372 ('a', 'DET')                ('to', 'TO')
# 373 ('burger', 'NOUN')          ('wait', 'VB')
# 374 ('stuffed', 'VERB')         ('very', 'RB')
# 375 ('with', 'ADP')             ('long', 'RB')
# 376 ('cheese', 'NOUN')          ('.', '.')
# 377 ('that', 'PRON')            ('What', 'WP')
# 378 ('melt', 'VERB')            ('an', 'DT')
# 379 ('##s', 'VERB')             ('attractive', 'JJ')
# 380 ('inside', 'ADV')           ('serving', 'NN')
# 381 ('.', 'PUNCT')              ('.', '.')
# 382 ('.', 'PUNCT')              ('With', 'IN')
# 383 ('.', 'PUNCT')              ('the', 'DT')
# 384 ('yu', 'INTJ')              ('strawberry', 'NN')
# 385 ('##m', 'INTJ')             ('topping', 'NN')
# 386 ('!', 'PUNCT')              ('and', 'CC')
# 387 ('although', 'SCONJ')       ('tax', 'NN')
# 388 ('we', 'PRON')              ('it', 'PRP')
# 389 ('were', 'AUX')             ('came', 'VBD')
# 390 ('just', 'ADV')             ('out', 'RP')
# 391 ('there', 'ADV')            ('to', 'TO')
# 392 ('for', 'ADP')              ('about', 'IN')
# 393 ('a', 'DET')                ('10', 'CD')
# 394 ('funnel', 'NOUN')          ('bucks', 'NNS')
# 395 ('cake', 'NOUN')            ('.', '.')
# 396 ('i', 'PRON')               ('Icing', 'VBG')
# 397 ('didn', 'AUX')             ('sugar', 'NN')
# 398 ("'", 'PUNCT')              (',', ',')
# 399 ('t', 'PART')               ('hot', 'JJ')
# 400 ('have', 'VERB')            (',', ',')
# 401 ('to', 'PART')              ('crunchy', 'JJ')
# 402 ('wait', 'VERB')            (',', ',')
# 403 ('very', 'ADV')             ('doughy', 'JJ')
# 404 ('long', 'ADV')             ('and', 'CC')
# 405 ('.', 'PUNCT')              ('just', 'RB')
# 406 ('what', 'DET')             ('plain', 'RB')
# 407 ('an', 'DET')               ('good', 'JJ')
# 408 ('attractive', 'ADJ')       ('.', '.')
# 409 ('serving', 'NOUN')         ('It', 'PRP')
# 410 ('.', 'PUNCT')              ('was', 'VBD')
# 411 ('with', 'ADP')             ('a', 'DT')
# 412 ('the', 'DET')              ('perfect', 'JJ')
# 413 ('strawberry', 'NOUN')      ('dessert', 'NN')
# 414 ('topping', 'NOUN')         ('to', 'TO')
# 415 ('and', 'CCONJ')            ('share', 'NN')
# 416 ('tax', 'NOUN')             ('after', 'IN')
# 417 ('it', 'PRON')              ('having', 'VBG')
# 418 ('came', 'VERB')            ('a', 'DT')
# 419 ('out', 'ADV')              ('spicy', 'NN')
# 420 ('to', 'ADP')               ('and', 'CC')
# 421 ('about', 'ADV')            ('savory', 'JJ')
# 422 ('10', 'NUM')               ('meal', 'NN')
# 423 ('bucks', 'NOUN')           ('across', 'IN')
# 424 ('.', 'PUNCT')              ('the', 'DT')
# 425 ('ic', 'NOUN')              ('parking', 'NN')
# 426 ('##ing', 'VERB')           ('lot', 'NN')
# 427 ('sugar', 'NOUN')           ('.', '.')
# 428 (',', 'PUNCT')              ('As', 'IN')
# 429 ('hot', 'ADJ')              ('for', 'IN')
# 430 (',', 'PUNCT')              ('the', 'DT')
# 431 ('crunch', 'ADJ')           ('burgers', 'NNS')
# 432 ('##y', 'ADJ')              ('that', 'WDT')
# 433 (',', 'PUNCT')              ("'ll", 'MD')
# 434 ('dough', 'ADJ')            ('have', 'VB')
# 435 ('##y', 'ADJ')              ('to', 'TO')
# 436 ('and', 'CCONJ')            ('be', 'VB')
# 437 ('just', 'ADV')             ('another', 'DT')
# 438 ('plain', 'ADV')            ('visit', 'NN')
# 439 ('good', 'ADJ')             ('but', 'CC')
# 440 ('.', 'PUNCT')              ('I', 'PRP')
# 441 ('it', 'PRON')              ("'m", 'VBP')
# 442 ('was', 'AUX')              ('already', 'RB')
# 443 ('a', 'DET')                ('looking', 'VBG')
# 444 ('perfect', 'ADJ')          ('forward', 'RB')
# 445 ('dessert', 'NOUN')         ('to', 'TO')
# 446 ('to', 'PART')              ('it', 'PRP')
# 447 ('share', 'VERB')           ('.', '.')
# 448 ('after', 'SCONJ')
# 449 ('having', 'VERB')
# 450 ('a', 'DET')
# 451 ('spicy', 'ADJ')
# 452 ('and', 'CCONJ')
# 453 ('sa', 'ADJ')
# 454 ('##vor', 'ADJ')
# 455 ('##y', 'ADJ')
# 456 ('meal', 'NOUN')
# 457 ('across', 'ADP')
# 458 ('the', 'DET')
# 459 ('parking', 'NOUN')
# 460 ('lot', 'NOUN')
# 461 ('.', 'PUNCT')
# 462 ('as', 'ADP')
# 463 ('for', 'ADP')
# 464 ('the', 'DET')
# 465 ('burger', 'NOUN')
# 466 ('##s', 'NOUN')
# 467 ('that', 'PRON')
# 468 ("'", 'AUX')
# 469 ('ll', 'AUX')
# 470 ('have', 'VERB')
# 471 ('to', 'PART')
# 472 ('be', 'AUX')
# 473 ('another', 'DET')
# 474 ('visit', 'NOUN')
# 475 ('but', 'CCONJ')
# 476 ('i', 'PRON')
# 477 ("'", 'AUX')
# 478 ('m', 'AUX')
# 479 ('already', 'ADV')
# 480 ('looking', 'VERB')
# 481 ('forward', 'ADV')
# 482 ('to', 'ADP')
# 483 ('it', 'PRON')
# 484 ('.', 'PUNCT')

# %% [markdown]
# ### Review 5

# %%
i = 4
review = samples.text[i]
print(review)
# Out:
# I had no idea a Waffles INCaffeinated was coming to the Wexford area. I've never been to one before but I have heard of it. I was on the NoWait app the other day going somewhere else for breakfast and Waffles INC popped up (Yes, they are on NoWait!). I didn't go that day but told myself to try it soon.
#
# I tried it today and I was pleasantly surprised. It's located in the plaza right in front of North Allegheny Senior High School. If you drive too fast, you might miss it. The sign outside is a little small. The environment itself is pretty small too but quaint enough to be a nice-sized diner. It wasn't too busy so we sat down right away.
#
# They have  a large menu filled with unique breakfast items like chicken and waffles, Eggs Benedict called "Benny" with a waffle substituted for the english muffin and topped with crab, and the "Breakfast Magic," which is what I got. It's a waffle with bacon, cheddar cheese, and green onions cooked into the waffle topped with more bacon and cheese as well as a sunny-side-up egg. You can even create your own waffles, omelettes, and crepes with a large array of fillings and toppings. Also, the portion sizes are pretty large.
#
# I'm a big coffee person so great coffee is key. They have their own brew and I approve of it. You can even pay fifty cents extra to include a shot of flavoring such as gingerbread. You are given a small cup full of the syrup so you can accordingly add it to your coffee. The coffee cups are a little small for my preference but the coffee itself is great.
#
# If you're looking to try something different for brunch other than your typical eggs and bacon, try this place!

# %%
bert_tags = bert_generate_tags(review)
nltk_tags = nltk_generate_tags(review)

# %%
print("BERT POS Tagging:             NLTK POS Tagging:")
for i in range(len(bert_tags)):
    if i >= len(nltk_tags):
        print(i,bert_tags[i])
    else:
        print(f"{i} {str(bert_tags[i]):28}{nltk_tags[i]}")
# Out:
# BERT POS Tagging:             NLTK POS Tagging:
# 0 ('i', 'PRON')               ('I', 'PRP')
# 1 ('had', 'VERB')             ('had', 'VBD')
# 2 ('no', 'DET')               ('no', 'DT')
# 3 ('idea', 'NOUN')            ('idea', 'NN')
# 4 ('a', 'DET')                ('a', 'DT')
# 5 ('wa', 'NOUN')              ('Waffles', 'NNP')
# 6 ('##ffle', 'NOUN')          ('INCaffeinated', 'NNP')
# 7 ('##s', 'PROPN')            ('was', 'VBD')
# 8 ('inca', 'ADJ')             ('coming', 'VBG')
# 9 ('##ffe', 'ADJ')            ('to', 'TO')
# 10 ('##inated', 'ADJ')         ('the', 'DT')
# 11 ('was', 'AUX')              ('Wexford', 'NNP')
# 12 ('coming', 'VERB')          ('area', 'NN')
# 13 ('to', 'ADP')               ('.', '.')
# 14 ('the', 'DET')              ('I', 'PRP')
# 15 ('wexford', 'PROPN')        ("'ve", 'VBP')
# 16 ('area', 'NOUN')            ('never', 'RB')
# 17 ('.', 'PUNCT')              ('been', 'VBN')
# 18 ('i', 'PRON')               ('to', 'TO')
# 19 ("'", 'AUX')                ('one', 'CD')
# 20 ('ve', 'AUX')               ('before', 'IN')
# 21 ('never', 'ADV')            ('but', 'CC')
# 22 ('been', 'AUX')             ('I', 'PRP')
# 23 ('to', 'ADP')               ('have', 'VBP')
# 24 ('one', 'NUM')              ('heard', 'VBN')
# 25 ('before', 'ADV')           ('of', 'IN')
# 26 ('but', 'CCONJ')            ('it', 'PRP')
# 27 ('i', 'PRON')               ('.', '.')
# 28 ('have', 'AUX')             ('I', 'PRP')
# 29 ('heard', 'VERB')           ('was', 'VBD')
# 30 ('of', 'ADP')               ('on', 'IN')
# 31 ('it', 'PRON')              ('the', 'DT')
# 32 ('.', 'PUNCT')              ('NoWait', 'NNP')
# 33 ('i', 'PRON')               ('app', 'VBP')
# 34 ('was', 'AUX')              ('the', 'DT')
# 35 ('on', 'ADP')               ('other', 'JJ')
# 36 ('the', 'DET')              ('day', 'NN')
# 37 ('now', 'PROPN')            ('going', 'VBG')
# 38 ('##ai', 'PROPN')           ('somewhere', 'RB')
# 39 ('##t', 'PROPN')            ('else', 'RB')
# 40 ('app', 'NOUN')             ('for', 'IN')
# 41 ('the', 'DET')              ('breakfast', 'NN')
# 42 ('other', 'ADJ')            ('and', 'CC')
# 43 ('day', 'NOUN')             ('Waffles', 'NNP')
# 44 ('going', 'VERB')           ('INC', 'NNP')
# 45 ('somewhere', 'ADV')        ('popped', 'VBD')
# 46 ('else', 'ADV')             ('up', 'RP')
# 47 ('for', 'ADP')              ('(', '(')
# 48 ('breakfast', 'NOUN')       ('Yes', 'UH')
# 49 ('and', 'CCONJ')            (',', ',')
# 50 ('wa', 'PROPN')             ('they', 'PRP')
# 51 ('##ffle', 'PROPN')         ('are', 'VBP')
# 52 ('##s', 'PROPN')            ('on', 'IN')
# 53 ('inc', 'PROPN')            ('NoWait', 'NNP')
# 54 ('popped', 'VERB')          ('!', '.')
# 55 ('up', 'ADP')               (')', ')')
# 56 ('(', 'PUNCT')              ('.', '.')
# 57 ('yes', 'INTJ')             ('I', 'PRP')
# 58 (',', 'PUNCT')              ('did', 'VBD')
# 59 ('they', 'PRON')            ("n't", 'RB')
# 60 ('are', 'AUX')              ('go', 'VB')
# 61 ('on', 'ADP')               ('that', 'DT')
# 62 ('now', 'PROPN')            ('day', 'NN')
# 63 ('##ai', 'PROPN')           ('but', 'CC')
# 64 ('##t', 'PROPN')            ('told', 'VBD')
# 65 ('!', 'PUNCT')              ('myself', 'PRP')
# 66 (')', 'PUNCT')              ('to', 'TO')
# 67 ('.', 'PUNCT')              ('try', 'VB')
# 68 ('i', 'PRON')               ('it', 'PRP')
# 69 ('didn', 'AUX')             ('soon', 'RB')
# 70 ("'", 'PART')               ('.', '.')
# 71 ('t', 'PART')               ('I', 'PRP')
# 72 ('go', 'VERB')              ('tried', 'VBD')
# 73 ('that', 'DET')             ('it', 'PRP')
# 74 ('day', 'NOUN')             ('today', 'NN')
# 75 ('but', 'CCONJ')            ('and', 'CC')
# 76 ('told', 'VERB')            ('I', 'PRP')
# 77 ('myself', 'PRON')          ('was', 'VBD')
# 78 ('to', 'PART')              ('pleasantly', 'RB')
# 79 ('try', 'VERB')             ('surprised', 'VBN')
# 80 ('it', 'PRON')              ('.', '.')
# 81 ('soon', 'ADV')             ('It', 'PRP')
# 82 ('.', 'PUNCT')              ("'s", 'VBZ')
# 83 ('i', 'PRON')               ('located', 'VBN')
# 84 ('tried', 'VERB')           ('in', 'IN')
# 85 ('it', 'PRON')              ('the', 'DT')
# 86 ('today', 'NOUN')           ('plaza', 'NN')
# 87 ('and', 'CCONJ')            ('right', 'NN')
# 88 ('i', 'PRON')               ('in', 'IN')
# 89 ('was', 'AUX')              ('front', 'NN')
# 90 ('pleasantly', 'ADV')       ('of', 'IN')
# 91 ('surprised', 'ADJ')        ('North', 'NNP')
# 92 ('.', 'PUNCT')              ('Allegheny', 'NNP')
# 93 ('it', 'PRON')              ('Senior', 'NNP')
# 94 ("'", 'AUX')                ('High', 'NNP')
# 95 ('s', 'AUX')                ('School', 'NNP')
# 96 ('located', 'VERB')         ('.', '.')
# 97 ('in', 'ADP')               ('If', 'IN')
# 98 ('the', 'DET')              ('you', 'PRP')
# 99 ('plaza', 'NOUN')           ('drive', 'VBP')
# 100 ('right', 'ADV')            ('too', 'RB')
# 101 ('in', 'ADP')               ('fast', 'RB')
# 102 ('front', 'NOUN')           (',', ',')
# 103 ('of', 'ADP')               ('you', 'PRP')
# 104 ('north', 'PROPN')          ('might', 'MD')
# 105 ('allegheny', 'PROPN')      ('miss', 'VB')
# 106 ('senior', 'PROPN')         ('it', 'PRP')
# 107 ('high', 'PROPN')           ('.', '.')
# 108 ('school', 'PROPN')         ('The', 'DT')
# 109 ('.', 'PUNCT')              ('sign', 'NN')
# 110 ('if', 'SCONJ')             ('outside', 'NN')
# 111 ('you', 'PRON')             ('is', 'VBZ')
# 112 ('drive', 'VERB')           ('a', 'DT')
# 113 ('too', 'ADV')              ('little', 'JJ')
# 114 ('fast', 'ADV')             ('small', 'JJ')
# 115 (',', 'PUNCT')              ('.', '.')
# 116 ('you', 'PRON')             ('The', 'DT')
# 117 ('might', 'AUX')            ('environment', 'NN')
# 118 ('miss', 'VERB')            ('itself', 'PRP')
# 119 ('it', 'PRON')              ('is', 'VBZ')
# 120 ('.', 'PUNCT')              ('pretty', 'RB')
# 121 ('the', 'DET')              ('small', 'JJ')
# 122 ('sign', 'NOUN')            ('too', 'RB')
# 123 ('outside', 'ADV')          ('but', 'CC')
# 124 ('is', 'AUX')               ('quaint', 'RB')
# 125 ('a', 'DET')                ('enough', 'RB')
# 126 ('little', 'ADJ')           ('to', 'TO')
# 127 ('small', 'ADJ')            ('be', 'VB')
# 128 ('.', 'PUNCT')              ('a', 'DT')
# 129 ('the', 'DET')              ('nice-sized', 'JJ')
# 130 ('environment', 'NOUN')     ('diner', 'NN')
# 131 ('itself', 'PRON')          ('.', '.')
# 132 ('is', 'AUX')               ('It', 'PRP')
# 133 ('pretty', 'ADV')           ('was', 'VBD')
# 134 ('small', 'ADJ')            ("n't", 'RB')
# 135 ('too', 'ADV')              ('too', 'RB')
# 136 ('but', 'CCONJ')            ('busy', 'JJ')
# 137 ('qu', 'ADJ')               ('so', 'IN')
# 138 ('##aint', 'ADJ')           ('we', 'PRP')
# 139 ('enough', 'ADV')           ('sat', 'VBP')
# 140 ('to', 'PART')              ('down', 'RP')
# 141 ('be', 'AUX')               ('right', 'RB')
# 142 ('a', 'DET')                ('away', 'RB')
# 143 ('nice', 'ADJ')             ('.', '.')
# 144 ('-', 'PUNCT')              ('They', 'PRP')
# 145 ('sized', 'ADJ')            ('have', 'VBP')
# 146 ('diner', 'NOUN')           ('a', 'DT')
# 147 ('.', 'PUNCT')              ('large', 'JJ')
# 148 ('it', 'PRON')              ('menu', 'NN')
# 149 ('wasn', 'AUX')             ('filled', 'VBN')
# 150 ("'", 'PUNCT')              ('with', 'IN')
# 151 ('t', 'PART')               ('unique', 'JJ')
# 152 ('too', 'ADV')              ('breakfast', 'NN')
# 153 ('busy', 'ADJ')             ('items', 'NNS')
# 154 ('so', 'ADV')               ('like', 'IN')
# 155 ('we', 'PRON')              ('chicken', 'NN')
# 156 ('sat', 'VERB')             ('and', 'CC')
# 157 ('down', 'ADV')             ('waffles', 'NNS')
# 158 ('right', 'ADV')            (',', ',')
# 159 ('away', 'ADV')             ('Eggs', 'NNP')
# 160 ('.', 'PUNCT')              ('Benedict', 'NNP')
# 161 ('they', 'PRON')            ('called', 'VBD')
# 162 ('have', 'VERB')            ('``', '``')
# 163 ('a', 'DET')                ('Benny', 'NNP')
# 164 ('large', 'ADJ')            ("''", "''")
# 165 ('menu', 'NOUN')            ('with', 'IN')
# 166 ('filled', 'VERB')          ('a', 'DT')
# 167 ('with', 'ADP')             ('waffle', 'NN')
# 168 ('unique', 'ADJ')           ('substituted', 'VBN')
# 169 ('breakfast', 'NOUN')       ('for', 'IN')
# 170 ('items', 'NOUN')           ('the', 'DT')
# 171 ('like', 'ADP')             ('english', 'JJ')
# 172 ('chicken', 'NOUN')         ('muffin', 'NN')
# 173 ('and', 'CCONJ')            ('and', 'CC')
# 174 ('wa', 'NOUN')              ('topped', 'VBD')
# 175 ('##ffle', 'NOUN')          ('with', 'IN')
# 176 ('##s', 'NOUN')             ('crab', 'NN')
# 177 (',', 'PUNCT')              (',', ',')
# 178 ('eggs', 'NOUN')            ('and', 'CC')
# 179 ('benedict', 'NOUN')        ('the', 'DT')
# 180 ('called', 'VERB')          ('``', '``')
# 181 ('"', 'PUNCT')              ('Breakfast', 'NNP')
# 182 ('benny', 'PROPN')          ('Magic', 'NNP')
# 183 ('"', 'PUNCT')              (',', ',')
# 184 ('with', 'ADP')             ("''", "''")
# 185 ('a', 'DET')                ('which', 'WDT')
# 186 ('wa', 'NOUN')              ('is', 'VBZ')
# 187 ('##ffle', 'NOUN')          ('what', 'WP')
# 188 ('substituted', 'VERB')     ('I', 'PRP')
# 189 ('for', 'ADP')              ('got', 'VBD')
# 190 ('the', 'DET')              ('.', '.')
# 191 ('english', 'ADJ')          ('It', 'PRP')
# 192 ('mu', 'NOUN')              ("'s", 'VBZ')
# 193 ('##ffin', 'NOUN')          ('a', 'DT')
# 194 ('and', 'CCONJ')            ('waffle', 'NN')
# 195 ('topped', 'VERB')          ('with', 'IN')
# 196 ('with', 'ADP')             ('bacon', 'NN')
# 197 ('crab', 'NOUN')            (',', ',')
# 198 (',', 'PUNCT')              ('cheddar', 'NN')
# 199 ('and', 'CCONJ')            ('cheese', 'NN')
# 200 ('the', 'DET')              (',', ',')
# 201 ('"', 'PUNCT')              ('and', 'CC')
# 202 ('breakfast', 'NOUN')       ('green', 'JJ')
# 203 ('magic', 'NOUN')           ('onions', 'NNS')
# 204 (',', 'PUNCT')              ('cooked', 'VBD')
# 205 ('"', 'PUNCT')              ('into', 'IN')
# 206 ('which', 'PRON')           ('the', 'DT')
# 207 ('is', 'AUX')               ('waffle', 'NN')
# 208 ('what', 'PRON')            ('topped', 'VBD')
# 209 ('i', 'PRON')               ('with', 'IN')
# 210 ('got', 'VERB')             ('more', 'RBR')
# 211 ('.', 'PUNCT')              ('bacon', 'NN')
# 212 ('it', 'PRON')              ('and', 'CC')
# 213 ("'", 'AUX')                ('cheese', 'NN')
# 214 ('s', 'AUX')                ('as', 'RB')
# 215 ('a', 'DET')                ('well', 'RB')
# 216 ('wa', 'NOUN')              ('as', 'IN')
# 217 ('##ffle', 'NOUN')          ('a', 'DT')
# 218 ('with', 'ADP')             ('sunny-side-up', 'JJ')
# 219 ('bacon', 'NOUN')           ('egg', 'NN')
# 220 (',', 'PUNCT')              ('.', '.')
# 221 ('che', 'NOUN')             ('You', 'PRP')
# 222 ('##dda', 'NOUN')           ('can', 'MD')
# 223 ('##r', 'PROPN')            ('even', 'RB')
# 224 ('cheese', 'NOUN')          ('create', 'VB')
# 225 (',', 'PUNCT')              ('your', 'PRP$')
# 226 ('and', 'CCONJ')            ('own', 'JJ')
# 227 ('green', 'ADJ')            ('waffles', 'NNS')
# 228 ('onions', 'NOUN')          (',', ',')
# 229 ('cooked', 'VERB')          ('omelettes', 'NNS')
# 230 ('into', 'ADP')             (',', ',')
# 231 ('the', 'DET')              ('and', 'CC')
# 232 ('wa', 'NOUN')              ('crepes', 'NNS')
# 233 ('##ffle', 'NOUN')          ('with', 'IN')
# 234 ('topped', 'VERB')          ('a', 'DT')
# 235 ('with', 'ADP')             ('large', 'JJ')
# 236 ('more', 'ADJ')             ('array', 'NN')
# 237 ('bacon', 'NOUN')           ('of', 'IN')
# 238 ('and', 'CCONJ')            ('fillings', 'NNS')
# 239 ('cheese', 'NOUN')          ('and', 'CC')
# 240 ('as', 'ADV')               ('toppings', 'NNS')
# 241 ('well', 'ADV')             ('.', '.')
# 242 ('as', 'ADP')               ('Also', 'RB')
# 243 ('a', 'DET')                (',', ',')
# 244 ('sunny', 'ADJ')            ('the', 'DT')
# 245 ('-', 'PUNCT')              ('portion', 'NN')
# 246 ('side', 'NOUN')            ('sizes', 'NNS')
# 247 ('-', 'PUNCT')              ('are', 'VBP')
# 248 ('up', 'ADP')               ('pretty', 'RB')
# 249 ('egg', 'NOUN')             ('large', 'JJ')
# 250 ('.', 'PUNCT')              ('.', '.')
# 251 ('you', 'PRON')             ('I', 'PRP')
# 252 ('can', 'AUX')              ("'m", 'VBP')
# 253 ('even', 'ADV')             ('a', 'DT')
# 254 ('create', 'VERB')          ('big', 'JJ')
# 255 ('your', 'PRON')            ('coffee', 'NN')
# 256 ('own', 'ADJ')              ('person', 'NN')
# 257 ('wa', 'NOUN')              ('so', 'RB')
# 258 ('##ffle', 'NOUN')          ('great', 'JJ')
# 259 ('##s', 'NOUN')             ('coffee', 'NN')
# 260 (',', 'PUNCT')              ('is', 'VBZ')
# 261 ('om', 'NOUN')              ('key', 'JJ')
# 262 ('##ele', 'NOUN')           ('.', '.')
# 263 ('##ttes', 'NOUN')          ('They', 'PRP')
# 264 (',', 'PUNCT')              ('have', 'VBP')
# 265 ('and', 'CCONJ')            ('their', 'PRP$')
# 266 ('cr', 'NOUN')              ('own', 'JJ')
# 267 ('##ep', 'NOUN')            ('brew', 'NN')
# 268 ('##es', 'NOUN')            ('and', 'CC')
# 269 ('with', 'ADP')             ('I', 'PRP')
# 270 ('a', 'DET')                ('approve', 'VBP')
# 271 ('large', 'ADJ')            ('of', 'IN')
# 272 ('array', 'NOUN')           ('it', 'PRP')
# 273 ('of', 'ADP')               ('.', '.')
# 274 ('filling', 'NOUN')         ('You', 'PRP')
# 275 ('##s', 'NOUN')             ('can', 'MD')
# 276 ('and', 'CCONJ')            ('even', 'RB')
# 277 ('topping', 'NOUN')         ('pay', 'VB')
# 278 ('##s', 'NOUN')             ('fifty', 'JJ')
# 279 ('.', 'PUNCT')              ('cents', 'NNS')
# 280 ('also', 'ADV')             ('extra', 'JJ')
# 281 (',', 'PUNCT')              ('to', 'TO')
# 282 ('the', 'DET')              ('include', 'VB')
# 283 ('portion', 'NOUN')         ('a', 'DT')
# 284 ('sizes', 'NOUN')           ('shot', 'NN')
# 285 ('are', 'AUX')              ('of', 'IN')
# 286 ('pretty', 'ADV')           ('flavoring', 'VBG')
# 287 ('large', 'ADJ')            ('such', 'JJ')
# 288 ('.', 'PUNCT')              ('as', 'IN')
# 289 ('i', 'PRON')               ('gingerbread', 'NN')
# 290 ("'", 'AUX')                ('.', '.')
# 291 ('m', 'AUX')                ('You', 'PRP')
# 292 ('a', 'DET')                ('are', 'VBP')
# 293 ('big', 'ADJ')              ('given', 'VBN')
# 294 ('coffee', 'NOUN')          ('a', 'DT')
# 295 ('person', 'NOUN')          ('small', 'JJ')
# 296 ('so', 'ADV')               ('cup', 'NN')
# 297 ('great', 'ADJ')            ('full', 'JJ')
# 298 ('coffee', 'NOUN')          ('of', 'IN')
# 299 ('is', 'AUX')               ('the', 'DT')
# 300 ('key', 'ADJ')              ('syrup', 'NN')
# 301 ('.', 'PUNCT')              ('so', 'IN')
# 302 ('they', 'PRON')            ('you', 'PRP')
# 303 ('have', 'VERB')            ('can', 'MD')
# 304 ('their', 'PRON')           ('accordingly', 'RB')
# 305 ('own', 'ADJ')              ('add', 'VB')
# 306 ('brew', 'NOUN')            ('it', 'PRP')
# 307 ('and', 'CCONJ')            ('to', 'TO')
# 308 ('i', 'PRON')               ('your', 'PRP$')
# 309 ('approve', 'VERB')         ('coffee', 'NN')
# 310 ('of', 'ADP')               ('.', '.')
# 311 ('it', 'PRON')              ('The', 'DT')
# 312 ('.', 'PUNCT')              ('coffee', 'NN')
# 313 ('you', 'PRON')             ('cups', 'NNS')
# 314 ('can', 'AUX')              ('are', 'VBP')
# 315 ('even', 'ADV')             ('a', 'DT')
# 316 ('pay', 'VERB')             ('little', 'JJ')
# 317 ('fifty', 'NUM')            ('small', 'JJ')
# 318 ('cents', 'NOUN')           ('for', 'IN')
# 319 ('extra', 'ADJ')            ('my', 'PRP$')
# 320 ('to', 'PART')              ('preference', 'NN')
# 321 ('include', 'VERB')         ('but', 'CC')
# 322 ('a', 'DET')                ('the', 'DT')
# 323 ('shot', 'NOUN')            ('coffee', 'NN')
# 324 ('of', 'ADP')               ('itself', 'PRP')
# 325 ('flavor', 'NOUN')          ('is', 'VBZ')
# 326 ('##ing', 'NOUN')           ('great', 'JJ')
# 327 ('such', 'ADJ')             ('.', '.')
# 328 ('as', 'ADP')               ('If', 'IN')
# 329 ('ginger', 'NOUN')          ('you', 'PRP')
# 330 ('##bread', 'NOUN')         ("'re", 'VBP')
# 331 ('.', 'PUNCT')              ('looking', 'VBG')
# 332 ('you', 'PRON')             ('to', 'TO')
# 333 ('are', 'AUX')              ('try', 'VB')
# 334 ('given', 'VERB')           ('something', 'NN')
# 335 ('a', 'DET')                ('different', 'JJ')
# 336 ('small', 'ADJ')            ('for', 'IN')
# 337 ('cup', 'NOUN')             ('brunch', 'NN')
# 338 ('full', 'ADJ')             ('other', 'JJ')
# 339 ('of', 'ADP')               ('than', 'IN')
# 340 ('the', 'DET')              ('your', 'PRP$')
# 341 ('syrup', 'NOUN')           ('typical', 'JJ')
# 342 ('so', 'ADV')               ('eggs', 'NNS')
# 343 ('you', 'PRON')             ('and', 'CC')
# 344 ('can', 'AUX')              ('bacon', 'NN')
# 345 ('accordingly', 'ADV')      (',', ',')
# 346 ('add', 'VERB')             ('try', 'VB')
# 347 ('it', 'PRON')              ('this', 'DT')
# 348 ('to', 'ADP')               ('place', 'NN')
# 349 ('your', 'PRON')            ('!', '.')
# 350 ('coffee', 'NOUN')
# 351 ('.', 'PUNCT')
# 352 ('the', 'DET')
# 353 ('coffee', 'NOUN')
# 354 ('cups', 'NOUN')
# 355 ('are', 'AUX')
# 356 ('a', 'DET')
# 357 ('little', 'ADJ')
# 358 ('small', 'ADJ')
# 359 ('for', 'ADP')
# 360 ('my', 'PRON')
# 361 ('preference', 'NOUN')
# 362 ('but', 'CCONJ')
# 363 ('the', 'DET')
# 364 ('coffee', 'NOUN')
# 365 ('itself', 'PRON')
# 366 ('is', 'AUX')
# 367 ('great', 'ADJ')
# 368 ('.', 'PUNCT')
# 369 ('if', 'SCONJ')
# 370 ('you', 'PRON')
# 371 ("'", 'AUX')
# 372 ('re', 'AUX')
# 373 ('looking', 'VERB')
# 374 ('to', 'PART')
# 375 ('try', 'VERB')
# 376 ('something', 'PRON')
# 377 ('different', 'ADJ')
# 378 ('for', 'ADP')
# 379 ('br', 'NOUN')
# 380 ('##un', 'NOUN')
# 381 ('##ch', 'NOUN')
# 382 ('other', 'ADJ')
# 383 ('than', 'ADP')
# 384 ('your', 'PRON')
# 385 ('typical', 'ADJ')
# 386 ('eggs', 'NOUN')
# 387 ('and', 'CCONJ')
# 388 ('bacon', 'NOUN')
# 389 (',', 'PUNCT')
# 390 ('try', 'VERB')
# 391 ('this', 'DET')
# 392 ('place', 'NOUN')
# 393 ('!', 'PUNCT')
